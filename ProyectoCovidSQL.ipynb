# %% [markdown]
# <a href="https://colab.research.google.com/github/BeatrizLlmz/ProyectosconSQL/blob/main/ProyectoCovidSQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis de datos sobre muertes y vacunaciones de Covid-19 desde febrero de 2020 hasta abril de 2021
#
#
# Primero daremos un vistazo a los datos

# %% [markdown]
# ![coviddeaths.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![covidvaccinations.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Muertes
# A continuación vamos a seleccionar las columnas que queremos utilizar de la tabla relacionada con las muertes.

# %% [markdown]
# ![used_data.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Lo siguiente será cambiar el formato de la columna fecha en la tabla de las muertes por covid, ya que ahora mismo es de tipo texto.

# %% [markdown]
# ![convert_date_deaths.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Y haremos lo mismo con la tabla de las vacunaciones.

# %% [markdown]
# ![convert_date_vaccinations.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Vamos con el análisis. La primera observación que haremos será de los casos totales vs las muertes totales en España

# %% [markdown]
# ![total_cases_vs_deaths.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# La siguiente consulta será para ver los casos totales vs la población

# %% [markdown]
# ![total_cases_vs_population.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# A continuación vamos a buscar los países con mayor ratio de infección comparado con la población.

# %% [markdown]
# ![infection_ratio.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Realizamos la misma consulta que la anterioe pero en este caso, con fechas.

# %% [markdown]
# ![infection_ratio_date.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# La siguiente observación será para los países con el mayor número de muertes por población

# %% [markdown]
# ![deaths_per_population.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Haremos la misma consulta pero por continentes.

# %% [markdown]
# ![deaths_per_continent.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Ahora veremos el número total de muertes por continente.

# %% [markdown]
# ![NUMBER_deaths_per_continent.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# A continuación, haremos un par de consultas que nos revelarán algunos números globales.

# %% [markdown]
# ![global_numbers_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![global_numbers_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Vacunaciones
#
# Lo siguiente será una consulta sobre la vacunación vs la población.

# %% [markdown]
# ![vaccinations_per_population.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Crearemos un CTE para obtener una columna con el porcentaje de la suma de los vacunados sobre la población.

# %% [markdown]
# ![CTE.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Por último, crearemos una vista para guardar esta información para futuras visualizaciones.

# %% [markdown]
# ![view.jpg](data:image/jpeg;base64,...)

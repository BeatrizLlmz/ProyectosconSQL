# %% [markdown]
# <a href="https://colab.research.google.com/github/BeatrizLlmz/ProyectosconSQL/blob/main/ProyectoAlojamientosSQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Limpieza de datos en SQL
#
# En este proyecto limpiaremos una base de datos de alojamientos en Nashville, Estados Unidos.
#
# Para comenzar echaremos un vistazo a los datos.

# %% [markdown]
# ![select_datos .jpg](data:image/jpeg;base64,...)

# %% [markdown]
# El siguiente paso será estandarizar el formato de la fecha.

# %% [markdown]
# ![convert_date.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Hay propiedades con la dirección vacía pero el mismo ParcelID que otra, por lo tanto la misma dirección, pero diferente UniqueID.
# Vamos a rellenar los datos faltantes con los datos que tenemos de las propiedades con mismo ParcelID y diferente UniqueID.

# %% [markdown]
# ![rellenar_datos.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# A continuación dividiremos la columna de la dirección en tres columnas individuales: dirección, ciudad y estado.

# %% [markdown]
# ![dividir_columna.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![dividir_columna2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![dividir_columna3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# En el campo "Sold As Vacant" cambiaremos la Y por Yes y la N por No para que sea más comprensible a simple vista.

# %% [markdown]
# ![sold_as_vacant.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Y para terminar con la limpeza vamos a borrar los duplicados y las columnas no usadas.

# %% [markdown]
# ![borrar_duplicados.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![borrar_columnas.jpg](data:image/jpeg;base64,...)
